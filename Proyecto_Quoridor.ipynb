# %% [markdown]
# # Librerías

# %%
import networkx as nx  # Librería clave para el proyecto

'''
# Importar función de borrado de pantalla de Google Colab
try:
    from IPython.display import clear_output 
    print("IPython.display.clear_output importado")
except:
    print("Error al importar IPython.display.clear_output")
# Importar función de borrado de pantalla de otros compiladores
'''
# Out:
# IPython.display.clear_output importado

# %% [markdown]
# # Clases

# %%
# ------------------------------------------------------------------------------
class Posicion:
    def __init__(self, x, y):
        self.x, self.y = x, y
    
    def setPos(self, x, y):
        self.x, self.y = x, y
    
    def getX(self):
        return self.x
    def getY(self):
        return self.y

class Jugador:
    # Funciones privadas
    def __limitar_direccion(self, d):
        if d < 0:
            return 0
        elif d > 3:
            return 3
        else:
            return d

    # Funciones públicas
    def __init__(self, nombre, direccion, tablero, muros):
        self.direccion, self.nombre, self.muros = self.__limitar_direccion(direccion), nombre, muros
        self.pos = Posicion(0, 0)

        if direccion == 0:
            self.pos.setPos(tablero.ancho // 2, 0)
        elif direccion == 1:
            self.pos.setPos(tablero.ancho // 2, tablero.alto - 1)
        elif direccion == 2:
            self.pos.setPos(tablero.ancho - 1, tablero.alto // 2)
        elif direccion == 3:
            self.pos.setPos(0, tablero.alto // 2)
        
        #  - - - - 0 - - - -
        #  - - - - v - - - -
        #  - - - - - - - - -
        #  - - - - - - - - -
        #  3 > - - - - - < 2
        #  - - - - - - - - -
        #  - - - - - - - - -
        #  - - - - ^ - - - -
        #  - - - - 1 - - - -

    def getDireccion(self):
        return self.direccion
    def getNombre(self):
        return self.nombre
    def getPos(self):
        return self.pos
    def getMuros(self):
        return self.muros

    def setMuros(self, muros):
        self.muros = muros

    def mover(self, tecla):
        if tecla == 's':  # Hacia abajo
            dx, dy = 0, 1
        elif tecla == 'w':  # Hacia arriba
            dx, dy = 0, -1
        elif tecla == 'a':  # Hacia la izquierda
            dx, dy = -1, 0
        elif tecla == 'd':  # Hacia la derecha
            dx, dy = 1, 0
        else:
            dx, dy = 0, 0

        self.pos.setPos(self.pos.getX() + dx, self.pos.getY() + dy)

# ------------------------------------------------------------------------------
class Tablero:
    def __init__(self, alto, ancho):
        self.alto = alto
        self.ancho = ancho
        # Prototipo de grafo
        self.grafo = [[] for i in range(alto)]
        for i in range(alto):
            for j in range(ancho):
                self.grafo[i].append(0)
        self.matriz_adyacencia = [[] for i in range(alto)]

    def getAlto(self):
        return self.alto
    def getAncho(self):
        return self.ancho
    def getGrafo(self):
        return self.grafo

# ------------------------------------------------------------------------------
class Juego:
    # Funciones privadas
    def __gamemode(self, modo):
        if modo < 0:
            return self.__gamemode(0)
        elif modo > 1:
            return self.__gamemode(1)
        else:
            # Si el modo de juego es 0 serán 2 jugadores, de lo contrario (y por defecto con el valor 1) serán 4
            return 2 if modo == 0 else 4

    def __crear_aristas(self, jugador, tablero):
        # Función usada tanto como por el jugador como la IA
        # Crear aristas cuando el jugador se encuentre con un muro u otro jugador
        pass

    def __fin_del_juego(self, jugador, tablero):
        d, x, y = jugador.getDireccion(), jugador.getPos().getX(), jugador.getPos().getY()
        alto, ancho = tablero.getAlto(), tablero.getAncho()

        if d == 0:
            if y == alto - 1:
                return True
        elif d == 1:
            if y == 0:
                return True
        elif d == 2:
            if x == 0:
                return True
        elif d == 3:
            if x == ancho - 1:
                return True
        return False
    
    def __mover_jugador(self, jugador, tablero, tecla):
        if (tecla == 'a' and jugador.getPos().getX() > 0) or \
           (tecla == 'd' and jugador.getPos().getX() < tablero.getAncho() - 1) or \
           (tecla == 'w' and jugador.getPos().getY() > 0) or \
           (tecla == 's' and jugador.getPos().getY() < tablero.getAlto() - 1):
            jugador.mover(tecla)

    def __usar_muro(self, jugador, tablero, tecla):
        if tecla == 'e':
            # Agregar código para eliminar los enlaces entre dos pares de nodos contiguos
            jugador.setMuros(jugador.getMuros() - 1)
    
    def __camino_optimo(self, jugadores, tablero):
        # Implementar la función Floyd-Warshall aquí y retornar los pasos a seguir para llegar a la meta
        # NOTA: En el caso de la función "__bot()" solo tomaría el primer elemento de la lista
        #       En el caso del jugador se le mostrará la lista de pasos a seguir como "camino sugerido"
        pass
    
    def __Bot(self, jugadores, tablero):
        # Escribir aquí el algoritmo de inteligencia artificial que usará el resto de jugadores.
        pass

    def __mostrar(self, jugadores, tablero):
        alto = tablero.getAlto()
        ancho = tablero.getAncho()
        num_jugadores = len(jugadores)

        for i in range(alto):
            linea = ""
            jugador_encontrado = False
            for j in range(ancho):
                c = ""
                for n in range(num_jugadores):
                    if jugadores[n].getPos().getX() == j and jugadores[n].getPos().getY() == i:
                        c = " " + jugadores[n].getNombre()
                        break
                    else:
                        c = " -"
                linea += c
            print(linea)

    # Funciones públicas
    def __init__(self, modo_de_juego):
        num_jugadores = self.__gamemode(modo_de_juego)
        
        self.juego_terminado = False
        self.tablero = Tablero(9, 9)
        self.jugadores = []
        for i in range(num_jugadores):
            self.jugadores.append(Jugador(str(i), i, self.tablero, 10))

    def ejecutar(self):
        ganador, turnos = "", 0
        num_jugadores = len(self.jugadores)

        while not self.juego_terminado:
            '''borrar_pantalla()'''

            # 1. Determinar si alguno de los jugadores ha ganado
            for i in range(len(self.jugadores)):
                if self.__fin_del_juego(self.jugadores[i], self.tablero):
                    self.juego_terminado = True
                    ganador = self.jugadores[i].getNombre()
                    break
            # 2. Continuar con el juego mientras que nadie haya ganado
            if not self.juego_terminado:
                self.__mostrar(self.jugadores, self.tablero)


                # NOTA: Por el momento todos los jugadores se controlarán de forma manual
                tecla = ''
                while True:
                    
                    tecla = input("TURNO JUGADOR " + self.jugadores[turnos%num_jugadores].getNombre() + ": ")
                    if tecla == 'a' or \
                       tecla == 'd' or \
                       tecla == 'w' or \
                       tecla == 's' or \
                       tecla == 'e':
                       break

                if num_jugadores == 2:
                    if turnos % num_jugadores == 0:
                        # Jugador
                        self.__mover_jugador(self.jugadores[0], self.tablero, tecla)
                        self.__usar_muro(self.jugadores[0], self.tablero, tecla)
                    elif turnos % num_jugadores == 1:
                        # IA 1
                        self.__mover_jugador(self.jugadores[1], self.tablero, tecla)
                        self.__usar_muro(self.jugadores[1], self.tablero, tecla)
                elif num_jugadores == 4:
                    if turnos % num_jugadores == 0:
                        # Jugador
                        self.__mover_jugador(self.jugadores[0], self.tablero, tecla)
                        self.__usar_muro(self.jugadores[0], self.tablero, tecla)
                    elif turnos % num_jugadores == 1:
                        # IA 1
                        self.__mover_jugador(self.jugadores[1], self.tablero, tecla)
                        self.__usar_muro(self.jugadores[1], self.tablero, tecla)
                    elif turnos % num_jugadores == 2:
                        # IA 2
                        self.__mover_jugador(self.jugadores[2], self.tablero, tecla)
                        self.__usar_muro(self.jugadores[2], self.tablero, tecla)
                    elif turnos % num_jugadores == 3:
                        # IA 3
                        self.__mover_jugador(self.jugadores[3], self.tablero, tecla)
                        self.__usar_muro(self.jugadores[3], self.tablero, tecla)

                if tecla == 'a' or \
                    tecla == 'd' or \
                    tecla == 'w' or \
                    tecla == 's' or \
                    tecla == 'e':
                    turnos += 1
        
        # 3. Al terminar el juego mostrar en pantalla quién ganó
        self.__mostrar(self.jugadores, self.tablero)
        print("¡El ganador es el jugador: " + ganador + "!")

# %% [markdown]
# # Cuerpo

# %%
'''
def borrar_pantalla():
    # Se probarán diferentes funciones de borrado de pantalla para que sea compatible con otros entornos
    # ------------------------------------------------------------------------------
    # Colab
    try:
        clear_output()
    except:
        print("clear_output() no existe")
    
    # Otros
    try:
        pass
    except:
        pass
'''

# %% [markdown]
# # Función principal

# %%
def main():
    quoridor = Juego(1) # Juego(modo_de_juego)
    quoridor.ejecutar()

# %% [markdown]
# # Inicializador

# %%
if __name__ == "__main__":
  main()
